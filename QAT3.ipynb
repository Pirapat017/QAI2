# %%
import pandas as pd
from pandas_datareader import data
import seaborn as sns
import matplotlib.pyplot as plt

# %%
stocks=['fb']
df = data.DataReader(stocks, data_source="yahoo",  start='2021-01-01', end='2021-12-23')
df.head()
# Out:
# Attributes   Adj Close       Close        High         Low        Open  \
# Symbols             fb          fb          fb          fb          fb
# Date
# 2020-12-31  273.160004  273.160004  277.089996  269.809998  272.000000
# 2021-01-04  268.940002  268.940002  275.000000  265.200012  274.779999
# 2021-01-05  270.970001  270.970001  272.399994  268.209991  268.290009
# 2021-01-06  263.309998  263.309998  267.750000  260.010010  262.000000
# 2021-01-07  268.739990  268.739990  271.609985  264.779999  265.899994
#
# Attributes    Volume
# Symbols           fb
# Date
# 2020-12-31  12900400
# 2021-01-04  15106100
# 2021-01-05   9871600
# 2021-01-06  24354100
# 2021-01-07  15789800

# %%
sns.lineplot(x=df.index, y='fb', data=df['Adj Close'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='fb'>

# %%
df['High']
# Out:
# Symbols             fb
# Date
# 2020-12-31  277.089996
# 2021-01-04  275.000000
# 2021-01-05  272.399994
# 2021-01-06  267.750000
# 2021-01-07  271.609985
# ...                ...
# 2021-12-17  337.109985
# 2021-12-20  329.899994
# 2021-12-21  336.000000
# 2021-12-22  334.510010
# 2021-12-23  336.670013
#
# [248 rows x 1 columns]

# %%
df['Low']
# Out:
# Symbols             fb
# Date
# 2020-12-31  269.809998
# 2021-01-04  265.200012
# 2021-01-05  268.209991
# 2021-01-06  260.010010
# 2021-01-07  264.779999
# ...                ...
# 2021-12-17  330.750000
# 2021-12-20  322.529999
# 2021-12-21  323.750000
# 2021-12-22  328.260010
# 2021-12-23  328.359985
#
# [248 rows x 1 columns]

# %%
high = 0
for i in range(len(df['High']['fb'])):
    high = df['High']['fb'][i] + high
Avg_high = high/248

print("ค่าเฉลี่ย",Avg_high)
# Out:
# ค่าเฉลี่ย 324.3447575722971
